# %% [markdown]
# <a href="https://colab.research.google.com/github/julmiha25-sys/MathStatistica/blob/main/%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0_%D0%B7%D0%B0%D1%80%D0%BF%D0%BB%D0%B0%D1%82%D1%8B_%D0%B2_%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8/%D0%93%D0%B8%D0%BF%D0%BE%D1%82%D0%B5%D0%B7%D0%B04_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy.stats import *
import scipy
import numpy as np
from scipy.stats import binomtest

df1 = pd.read_csv('Salary.csv', header=0)
# Преобразование типа
df1.loc[:, 'Опыт работы'] = df1['Опыт работы'].astype(int)
# Количество записей - размер выборки
n_v = len(df1.dropna(subset=['Уровень образования']))
alpha = 0.01
d = 0.15
# Определение доли людей со средним профессиональным образованием
df_v = df1[df1['Уровень образования'].isin(['среднее профессиональное'])]
result = binomtest(k=len(df_v), n=n_v, p=0.15, alternative='two-sided')
r = result.proportion_ci(confidence_level=1-alpha)

print("Доверительный интервал от", r[0], " до ", r[1])
print("Выборочная доля:", len(df_v)/len(df1))

if d > r[0] and d < r[1]:
    print(f"Гипотетическая доля {d} входит в доверительный интервал - Гипотезу Не ОТВЕРГАЕМ")
else:
    print(f"Гипотетическая доля {d} не входит в доверительный интервал - Гипотезу ОТВЕРГАЕМ")

# %% [markdown]
# ### Результат выполнения:
#
# ```
# Доверительный интервал от 0.10194348371097836 до 0.11904298356203585
# Выборочная доля: 0.0995
# Гипотетическая доля 0.15 не входит в доверительный интервал - Гипотезу ОТВЕРГАЕМ
# ```
